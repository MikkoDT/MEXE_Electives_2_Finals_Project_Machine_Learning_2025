# %% [markdown]
# ### **Extracting Files**

# %%
import os
import zipfile
import pandas as pd

zip_filename = "archive (2).zip"
extract_dir = "weather_data"

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_filename, "r") as zip_ref:
    zip_ref.extractall(extract_dir)

print("Files extracted!")

file_path = os.path.join(extract_dir, "philippines_typhoon_monthly_2014_2024.csv")
data = pd.read_csv(file_path)
# Out:
# Files extracted!

# %% [markdown]
# ### **Loading the Dataset**

# %%
print("📊 RAW DATA OVERVIEW")
display(data.head())
# Out:
# 📊 RAW DATA OVERVIEW
#    Month  Number_of_Typhoons   ONI  Nino3.4_SST_anomaly  Western_Pacific_SST  \
# 0      1                   1  0.03                -0.05                 0.36
# 1      2                   0  0.20                 0.18                -0.43
# 2      3                   0  0.02                 0.00                 0.01
# 3      4                   0  0.13                 0.07                -0.15
# 4      5                   0 -0.03                -0.05                -0.41
#
#    Midlevel_Humidity  SeaLevelPressure  MJO_Phase  Prev_month_typhoons  \
# 0               54.8            1009.8          0                    0
# 1               59.5            1009.5          7                    1
# 2               49.3            1009.4          6                    0
# 3               57.8            1008.2          0                    0
# 4               61.4            1008.1          3                    0
#
#    Vertical_Wind_Shear
# 0                 13.2
# 1                 13.8
# 2                 13.0
# 3                 10.7
# 4                 11.1

# %% [markdown]
# ### **Checking for Missing Values**

# %%
data.isnull().sum()
# Out:
# Month                  0
# Number_of_Typhoons     0
# ONI                    0
# Nino3.4_SST_anomaly    0
# Western_Pacific_SST    0
# Midlevel_Humidity      0
# SeaLevelPressure       0
# MJO_Phase              0
# Prev_month_typhoons    0
# Vertical_Wind_Shear    0
# dtype: int64

# %% [markdown]
# ### **Getting the Inputs and Outputs**

# %% [markdown]
# ### Independent Variables

# %%
X = data.iloc[:, :-1]   
X.head()
# Out:
#    Month  Number_of_Typhoons   ONI  Nino3.4_SST_anomaly  Western_Pacific_SST  \
# 0      1                   1  0.03                -0.05                 0.36
# 1      2                   0  0.20                 0.18                -0.43
# 2      3                   0  0.02                 0.00                 0.01
# 3      4                   0  0.13                 0.07                -0.15
# 4      5                   0 -0.03                -0.05                -0.41
#
#    Midlevel_Humidity  SeaLevelPressure  MJO_Phase  Prev_month_typhoons
# 0               54.8            1009.8          0                    0
# 1               59.5            1009.5          7                    1
# 2               49.3            1009.4          6                    0
# 3               57.8            1008.2          0                    0
# 4               61.4            1008.1          3                    0

# %% [markdown]
# ### Dependent Variables

# %%
y = data.iloc[:, -1]
y.head()
# Out:
# 0    13.2
# 1    13.8
# 2    13.0
# 3    10.7
# 4    11.1
# Name: Vertical_Wind_Shear, dtype: float64

# %% [markdown]
# ### **Scaling**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### **Creating the Training Set and the Test Set**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2,random_state=0)

# %%
X_train
# Out:
#      Month  Number_of_Typhoons   ONI  Nino3.4_SST_anomaly  \
# 63       4                   0  0.56                 0.52
# 71      12                   0  0.66                 0.59
# 86       3                   0 -0.91                -0.94
# 33      10                   5 -0.67                -0.63
# 129     10                   2  0.99                 0.94
# ..     ...                 ...   ...                  ...
# 9       10                   4 -0.01                 0.07
# 103      8                   1 -1.25                -1.27
# 67       8                   1  0.64                 0.70
# 117     10                   2  0.17                 0.20
# 47      12                   0  0.07                 0.00
#
#      Western_Pacific_SST  Midlevel_Humidity  SeaLevelPressure  MJO_Phase  \
# 63                  0.57               64.7            1007.7          0
# 71                 -0.10               54.8            1009.5          0
# 86                 -0.28               58.2            1009.4          4
# 33                 -0.26               64.6            1004.5          0
# 129                 0.31               59.2            1005.7          6
# ..                   ...                ...               ...        ...
# 9                  -0.32               60.7            1004.6          8
# 103                 0.13               67.6            1004.5          5
# 67                 -0.29               73.8            1004.6          3
# 117                -0.11               60.9            1005.1          3
# 47                  0.35               51.1            1009.3          7
#
#      Prev_month_typhoons
# 63                     0
# 71                     3
# 86                     1
# 33                     2
# 129                    3
# ..                   ...
# 9                      2
# 103                    5
# 67                     1
# 117                    5
# 47                     3
#
# [105 rows x 9 columns]

# %%
X_test
# Out:
#      Month  Number_of_Typhoons   ONI  Nino3.4_SST_anomaly  \
# 93      10                   3 -1.07                -0.96
# 66       7                   1  0.70                 0.73
# 26       3                   0 -0.53                -0.46
# 8        9                   2 -0.11                -0.05
# 30       7                   1 -0.47                -0.49
# 91       8                   3 -0.87                -0.90
# 109      2                   0  0.02                -0.03
# 100      5                   1 -1.15                -1.19
# 44       9                   2 -0.09                -0.14
# 101      6                   1 -1.32                -1.47
# 99       4                   1 -1.30                -1.29
# 56       9                   3 -0.38                -0.40
# 43       8                   2 -0.01                 0.04
# 96       1                   0 -0.93                -0.95
# 22      11                   3  1.49                 1.40
# 78       7                   2 -1.03                -1.03
# 95      12                   3 -0.75                -0.64
# 97       2                   0 -1.25                -1.29
# 7        8                   2  0.12                 0.05
# 24       1                   0 -0.45                -0.49
# 61       2                   0  0.67                 0.73
# 10      11                   1 -0.01                 0.04
# 108      1                   2  0.05                 0.06
# 45      10                   2 -0.16                -0.15
# 16       5                   1  1.61                 1.54
# 2        3                   0  0.02                 0.00
# 68       9                   1  0.49                 0.48
#
#      Western_Pacific_SST  Midlevel_Humidity  SeaLevelPressure  MJO_Phase  \
# 93                  0.63               65.2            1006.2          1
# 66                 -0.11               68.5            1006.1          8
# 26                 -0.41               51.0            1008.4          0
# 8                   0.33               73.1            1004.7          3
# 30                 -0.44               72.1            1004.9          3
# 91                  0.13               69.8            1005.5          4
# 109                 0.32               62.0            1008.3          6
# 100                -0.50               63.2            1007.7          5
# 44                 -0.02               67.6            1003.4          7
# 101                -0.03               75.7            1004.5          6
# 99                  0.31               63.2            1007.0          6
# 56                  0.49               67.9            1005.1          4
# 43                  0.54               70.8            1004.5          6
# 96                 -0.37               58.8            1010.4          2
# 22                  0.68               63.3            1007.2          5
# 78                  0.52               72.4            1006.2          6
# 95                  0.29               54.4            1010.0          6
# 97                 -0.26               57.7            1010.2          1
# 7                   0.13               70.0            1005.2          5
# 24                  0.14               58.0            1011.1          1
# 61                 -0.11               54.6            1008.9          1
# 10                 -0.27               63.3            1009.5          1
# 108                -0.48               57.2            1009.8          5
# 45                  0.41               64.0            1004.2          7
# 16                 -0.37               61.0            1007.6          3
# 2                   0.01               49.3            1009.4          6
# 68                  0.43               69.8            1005.9          2
#
#      Prev_month_typhoons
# 93                     2
# 66                     4
# 26                     0
# 8                      2
# 30                     3
# 91                     0
# 109                    2
# 100                    1
# 44                     2
# 101                    1
# 99                     0
# 56                     2
# 43                     4
# 96                     3
# 22                     1
# 78                     3
# 95                     1
# 97                     0
# 7                      3
# 24                     1
# 61                     1
# 10                     4
# 108                    0
# 45                     2
# 16                     0
# 2                      0
# 68                     1

# %%
y_train
# Out:
# 63     10.9
# 71     11.6
# 86     12.8
# 33      9.0
# 129     9.1
#        ...
# 9       9.4
# 103     8.1
# 67      7.9
# 117     9.3
# 47     12.3
# Name: Vertical_Wind_Shear, Length: 105, dtype: float64

# %%
y_test
# Out:
# 93      9.0
# 66      8.6
# 26     13.0
# 8       6.9
# 30      8.2
# 91      8.8
# 109    12.7
# 100    10.8
# 44      8.1
# 101     8.5
# 99     10.4
# 56      8.5
# 43      8.3
# 96     12.3
# 22      9.5
# 78      8.0
# 95     12.4
# 97     12.3
# 7       8.0
# 24     12.3
# 61     13.7
# 10     10.4
# 108    13.1
# 45      8.6
# 16     11.4
# 2      13.0
# 68      8.5
# Name: Vertical_Wind_Shear, dtype: float64

# %% [markdown]
# ## **Building the Training Model**

# %% [markdown]
# ### **Building the Model**

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# ### **Training the Model**

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Inference**

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 9.18679541,  9.35353832, 12.08255402,  7.80606333,  8.26848589,
#         8.38572827, 11.25446396, 10.5350408 ,  7.82312614,  7.7301682 ,
#        10.24287393,  8.46867888,  8.22804065, 12.64422259,  9.65587693,
#         8.89702869, 11.98289764, 12.36464909,  8.50572444, 12.86120924,
#        12.05641974, 11.11898453, 12.14792419,  8.52943446, 10.43744985,
#        12.84460103,  8.65084991])

# %%
comparison = pd.DataFrame({
    "Actual": y_test,
    "Predicted": y_pred
})

comparison.head()
# Out:
#     Actual  Predicted
# 93     9.0   9.186795
# 66     8.6   9.353538
# 26    13.0  12.082554
# 8      6.9   7.806063
# 30     8.2   8.268486

# %% [markdown]
# One data point, including Month, Number_of_Typhoons, ONI, Nino3.4_SST_anomaly,  Western Pacific SST, Midlevel_Humidity, SeaLevelPressure, MJO phase, and Prev_month_typhoon, is used for making the prediction of the Vertical Wind Shear.

# %%
sample = pd.DataFrame([[1,1,0.03,-0.05,0.36,54.8,1009.8,0,0]],
                      columns=X.columns)

model.predict(sample)
# Out:
# array([12.35877554])

# %%
# Pang test, para madaling makita ang data
print("📊 RAW DATA OVERVIEW")
display(data.head())
# Out:
# 📊 RAW DATA OVERVIEW
#    Month  Number_of_Typhoons   ONI  Nino3.4_SST_anomaly  Western_Pacific_SST  \
# 0      1                   1  0.03                -0.05                 0.36
# 1      2                   0  0.20                 0.18                -0.43
# 2      3                   0  0.02                 0.00                 0.01
# 3      4                   0  0.13                 0.07                -0.15
# 4      5                   0 -0.03                -0.05                -0.41
#
#    Midlevel_Humidity  SeaLevelPressure  MJO_Phase  Prev_month_typhoons  \
# 0               54.8            1009.8          0                    0
# 1               59.5            1009.5          7                    1
# 2               49.3            1009.4          6                    0
# 3               57.8            1008.2          0                    0
# 4               61.4            1008.1          3                    0
#
#    Vertical_Wind_Shear
# 0                 13.2
# 1                 13.8
# 2                 13.0
# 3                 10.7
# 4                 11.1

# %% [markdown]
# ## **Evaluating the Model**

# %% [markdown]
# ### **Mean Absolute Error**

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 0.5134824676879167

# %% [markdown]
# ### **Mean Squared Error**

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("MSE:", mse)
# Out:
# MSE: 0.4481871001037773

# %% [markdown]
# ### **R-Squared**

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8927303303580422

# %% [markdown]
# ### **Adjusted R-Squared**

# %%
k = X_test.shape[1]
n = X_test.shape[0]
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
adj_r2
# Out:
# 0.8359405052534763

# %% [markdown]
# 1. **Model Performance**
#
# The model achieved good/acceptable accuracy based on the R² and Adjusted R² values.
# This means the features (climate factors) explain a significant portion of the variation in Vertical Wind Shear.
#
# 2. **Error Analysis**
#
# The MAE and RMSE values show the average difference between predicted and actual values.
# Smaller values mean the model produces predictions close to the real data.
#
# 3. **Trends Observed**
#
# Based on the predictions, the model suggests stable and consistent wind shear patterns, indicating there are no extreme increases or drops for the months predicted.
